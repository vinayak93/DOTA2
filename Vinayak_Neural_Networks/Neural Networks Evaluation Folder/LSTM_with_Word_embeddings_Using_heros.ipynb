# %%
'''This notebook contains the LSTM model on top of CNN layer with word embeddings'''
# Out:
# 'This notebook contains the LSTM model on top of CNN layer with word embeddings'

# %%
#Credits https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
#https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/
#https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/

# %%
'''Import the necessary Libraries'''
import pandas as pd
import numpy as np
import datetime

import tensorflow as tf
import numpy
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

from itertools import chain

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve, GridSearchCV

from keras.utils import to_categorical

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
'''Now we load the required data sets'''
df = pd.read_csv("dataset_without_duplicates_Bans analysis.csv")
matrix1 =np.array(df.loc[:,['match_id','1hero_id','2hero_id','3hero_id','4hero_id']])
df1 = pd.read_csv("hero_names.csv")
matrix2 =np.array(df1.loc[:,['hero_id', 'Strength','Agility','Intelligence']])

def dataprep1(index):
    my_input = matrix1[:,1:index]
    my_output = matrix1[:,index]
    train_x = my_input[:40000,:]
    train_x = np.asarray(train_x).astype(np.float32)
    #train_x = tf.convert_to_tensor(train_x)
    train_y = my_output[:40000]
    train_y = np.asarray(train_y).astype(np.float32)
    #train_y = tf.convert_to_tensor(train_y)
    test_x = my_input[40000:50000,:]
    test_x = np.asarray(test_x).astype(np.float32)
    test_y = my_output[40000:50000]
    test_y = np.asarray(test_y).astype(np.float32)
    train_y_cat = to_categorical(train_y)
    #train_y_cat = tf.convert_to_tensor(train_y_cat)
    test_y_cat = to_categorical(test_y)
    #test_y_cat = tf.convert_to_tensor(test_y_cat)
    return train_x,train_y_cat,test_x,test_y_cat
#train_x,train_y_cat,test_x,test_y_cat = dataprep1(2)
#my_y_pred = model.predict(test_x)
#my_y_pred = np.array(my_y_pred)
#my_y_pred.shape

# %%
'''Defining the model with embeddings along with CNN and LSTM. I have used adam optimizer with categorical crossentropy as our model predicts multiple classes.'''
numpy.random.seed(7)
# create the model
def my_model(input_length_val,pool_size_val):
    embedding_vecor_length = 32
    model = Sequential()
    model.add(Embedding(114, embedding_vecor_length, input_length=input_length_val))
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=pool_size_val))
    model.add(LSTM(100,return_sequences=True))
    model.add(LSTM(100))
    model.add(Dense(113, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc',tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    print(model.summary())
    return model

# %%
import random as ra
for i in range(2,5):
    train_x,train_y_cat,test_x,test_y_cat = dataprep1(i)
    input_length_val = i-1
    if i==3:    
        pool_size_val = 2
        batch_size_val = 32
    elif i==4:
        pool_size_val = 3
        batch_size_val = 32
    elif i==2:
        pool_size_val = 1
        batch_size_val = 32
    
    model = my_model(input_length_val,pool_size_val)
    # fit the model
    model.fit(train_x, train_y_cat, epochs=2, batch_size=batch_size_val)
    #y_preds = model.predict(test_x)
    #print("Y PREDS ISSSS: ",y_preds)

    for j in range(0,7):
        small = ra.randint(0,9999)
        big = ra.randint(0,9999)
        while ((small>=big) and ((big-small)<500)):
            small = ra.randint(0,9999)
            big = ra.randint(0,9999)

    # evaluate the model
        print("Iteration Number: ",j)
        y_preds = model.predict(test_x[small:big,])
        y_preds_shaper = np.array(y_preds)
        
        for m in range(0,y_preds_shaper.shape[0]):
            index, max_val = -1, -1
            for k in range(0,y_preds_shaper.shape[1]):
                if y_preds[m,k] > max_val:
                    index, max_val = i, y_preds[m,k]
            for k in range(0,y_preds_shaper.shape[1]):
                if k==index:
                    y_preds[m,k]=1
                else:
                    y_preds[m,k]=0
            #loss, accuracy, precision, recall = model.evaluate(test_x[small:big,], test_y_cat[small:big], verbose=1)
        loss, accuracy, precision, recall = model.evaluate(y_preds, test_y_cat[small:big], verbose=1)
    #res = model.predict(test_x)
    #print("Res is:",res)
        print("loss is: ", loss)
        print("Accuracy is: ",accuracy)
        print("Precision is: ",precision)
        print("Recall is: ",recall)
        print("F1 is : ", 2*((precision*recall)/(precision+recall+K.epsilon())))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1, 32)             3648
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1, 32)             3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1, 32)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 100)            53200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 113)               11413
# =================================================================
# Total params: 151,765
# Trainable params: 151,765
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.4127 - acc: 0.1710 - precision: 0.4706 - recall: 2.0000e-04
# Epoch 2/2
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.2636 - acc: 0.2261 - precision: 0.5412 - recall: 0.0012
# Iteration Number:  0
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input Tensor("embedding_input:0", shape=(None, 1), dtype=float32), but it was called on an input with incompatible shape (None, 113).
# 8/8 [==============================] - 0s 30ms/step - loss: 3.9391 - acc: 0.1434 - precision: 0.1434 - recall: 0.1434
# loss is:  3.939124822616577
# Accuracy is:  0.14344261586666107
# Precision is:  0.14344261586666107
# Recall is:  0.14344261586666107
# F1 is :  0.1434425658666785
# Iteration Number:  1
# 17/17 [==============================] - 1s 36ms/step - loss: 4.2138 - acc: 0.1423 - precision: 0.1423 - recall: 0.1423
# loss is:  4.213758945465088
# Accuracy is:  0.14232902228832245
# Precision is:  0.14232902228832245
# Recall is:  0.14232902228832245
# F1 is :  0.14232897228834002
# Iteration Number:  2
# 204/204 [==============================] - 8s 41ms/step - loss: 4.3451 - acc: 0.1229 - precision: 0.1229 - recall: 0.1229
# loss is:  4.345075607299805
# Accuracy is:  0.12292307615280151
# Precision is:  0.12292307615280151
# Recall is:  0.12292307615280151
# F1 is :  0.12292302615282186
# Iteration Number:  3
# 80/80 [==============================] - 3s 34ms/step - loss: 4.3126 - acc: 0.1339 - precision: 0.1339 - recall: 0.1339
# loss is:  4.3126325607299805
# Accuracy is:  0.1339355856180191
# Precision is:  0.1339355856180191
# Recall is:  0.1339355856180191
# F1 is :  0.13393553561803778
# Iteration Number:  4
# 226/226 [==============================] - 8s 36ms/step - loss: 4.3677 - acc: 0.1201 - precision: 0.1201 - recall: 0.1201
# loss is:  4.367703914642334
# Accuracy is:  0.12010552734136581
# Precision is:  0.12010552734136581
# Recall is:  0.12010552734136581
# F1 is :  0.12010547734138663
# Iteration Number:  5
# 81/81 [==============================] - 3s 39ms/step - loss: 4.3598 - acc: 0.1342 - precision: 0.1342 - recall: 0.1342
# loss is:  4.359826564788818
# Accuracy is:  0.13423597812652588
# Precision is:  0.13423597812652588
# Recall is:  0.13423597812652588
# F1 is :  0.1342359281265445
# Iteration Number:  6
# 49/49 [==============================] - 2s 31ms/step - loss: 4.5215 - acc: 0.1059 - precision: 0.1059 - recall: 0.1059
# loss is:  4.521541118621826
# Accuracy is:  0.10594315081834793
# Precision is:  0.10594315081834793
# Recall is:  0.10594315081834793
# F1 is :  0.10594310081837152
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2, 32)             3648
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2, 32)             3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 100)            53200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 113)               11413
# =================================================================
# Total params: 151,765
# Trainable params: 151,765
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.7433 - acc: 0.1037 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2/2
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.5671 - acc: 0.1511 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Iteration Number:  0
# WARNING:tensorflow:Model was constructed with shape (None, 2) for input Tensor("embedding_1_input:0", shape=(None, 2), dtype=float32), but it was called on an input with incompatible shape (None, 113).
# 42/42 [==============================] - 1s 20ms/step - loss: 4.7258 - acc: 0.0886 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.725782871246338
# Accuracy is:  0.0885692685842514
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  1
# 141/141 [==============================] - 2s 17ms/step - loss: 4.6904 - acc: 0.0784 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.6903886795043945
# Accuracy is:  0.07839643955230713
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  2
# 35/35 [==============================] - 1s 18ms/step - loss: 4.6110 - acc: 0.0851 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.611044406890869
# Accuracy is:  0.08506787568330765
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  3
# 1/1 [==============================] - 0s 976us/step - loss: 4.0965 - acc: 0.0000e+00 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.0965166091918945
# Accuracy is:  0.0
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  4
# 7/7 [==============================] - 0s 15ms/step - loss: 4.8982 - acc: 0.0647 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.898155689239502
# Accuracy is:  0.06467662006616592
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  5
# 126/126 [==============================] - 3s 22ms/step - loss: 4.6566 - acc: 0.0828 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.656599521636963
# Accuracy is:  0.08275174349546432
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  6
# 210/210 [==============================] - 4s 21ms/step - loss: 4.6470 - acc: 0.0830 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# loss is:  4.646986484527588
# Accuracy is:  0.08300985395908356
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 3, 32)             3648
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 32)             3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 100)            53200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_2 (Dense)              (None, 113)               11413
# =================================================================
# Total params: 151,765
# Trainable params: 151,765
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2
# 1250/1250 [==============================] - 6s 5ms/step - loss: 3.7826 - acc: 0.0941 - precision_2: 0.5652 - recall_2: 3.2500e-04
# Epoch 2/2
# 1250/1250 [==============================] - 5s 4ms/step - loss: 3.6044 - acc: 0.1455 - precision_2: 0.5153 - recall_2: 0.0025
# Iteration Number:  0
# WARNING:tensorflow:Model was constructed with shape (None, 3) for input Tensor("embedding_2_input:0", shape=(None, 3), dtype=float32), but it was called on an input with incompatible shape (None, 113).
# 43/43 [==============================] - 1s 13ms/step - loss: 4.6953 - acc: 0.0503 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.695255279541016
# Accuracy is:  0.050295859575271606
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  1
# 23/23 [==============================] - 0s 11ms/step - loss: 4.7074 - acc: 0.0523 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.70741081237793
# Accuracy is:  0.052269600331783295
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  2
# 73/73 [==============================] - 1s 13ms/step - loss: 4.6565 - acc: 0.0498 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.6564717292785645
# Accuracy is:  0.04978355020284653
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  3
# 225/225 [==============================] - 3s 13ms/step - loss: 4.6211 - acc: 0.0527 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.621124744415283
# Accuracy is:  0.05267547070980072
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  4
# 26/26 [==============================] - 0s 10ms/step - loss: 4.5284 - acc: 0.0527 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.528375148773193
# Accuracy is:  0.05269607901573181
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  5
# 41/41 [==============================] - 0s 11ms/step - loss: 4.6516 - acc: 0.0483 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.651580810546875
# Accuracy is:  0.04834996163845062
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0
# Iteration Number:  6
# 43/43 [==============================] - 0s 11ms/step - loss: 4.6728 - acc: 0.0513 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# loss is:  4.672788619995117
# Accuracy is:  0.05130111426115036
# Precision is:  0.0
# Recall is:  0.0
# F1 is :  0.0

# %%
'''The cells below are to be ignored as they are testing cells only'''

# %%
#model.fit(train_x, train_y_cat, epochs=10, batch_size=32)
# Final evaluation of the model
##scores = model.evaluate(test_x, test_y_cat, verbose=1)
##print("Accuracy: %.2f%%" % (scores[1]*100))
#predict_classes(object, x, batch_size = NULL, verbose = 0, steps = NULL)
#class_vals = model.predict_classes(test_x, test_y_cat,verbose=1)
##print(scores)
#res = model.predict(test_x)

# %%
res
# Out:
# array([[4.6302646e-11, 2.0412136e-02, 5.5758455e-03, ..., 8.3727943e-04,
#         5.6127925e-11, 1.7126616e-02],
#        [2.5977874e-08, 2.4595298e-02, 8.7316809e-03, ..., 3.7359309e-03,
#         4.0153285e-08, 1.0456971e-02],
#        [2.5422263e-11, 1.6976409e-02, 7.7993367e-03, ..., 1.7016078e-04,
#         2.9651653e-11, 6.8962099e-03],
#        ...,
#        [5.0971623e-11, 2.0336319e-02, 3.6610698e-03, ..., 4.0176904e-04,
#         6.3429768e-11, 1.1689910e-02],
#        [1.1040675e-10, 2.7636470e-02, 3.2927773e-03, ..., 5.5798527e-04,
#         1.2071649e-10, 3.1962667e-02],
#        [2.1676995e-11, 3.9491843e-02, 4.2277668e-03, ..., 4.8325117e-05,
#         1.9527213e-11, 4.7792410e-03]], dtype=float32)

# %%
ypred4 = np.argmax(res, axis=1)
print("Ypred4", ypred4)
#total_predictions_correct_4 = sum(p == t for p, t in zip(test_y, ypred4))
#total_predictions_correct_4 = sum(p == t for p, t in zip(test_y_cat, res))
counter = 0 
for i in range(test_y_cat.shape[0]):
    if test_y_cat[i].all()==ypred4[i].all():
        counter=counter+1
#accuracy_4 = total_predictions_correct_4/test_y.shape[0]
accuracy_4 = counter/test_y_cat.shape[0]
print(accuracy_4)
# Out:
# Ypred4 [85 73 30 ... 69 85  7]
# 0.0

# %%
print(scores)
# Out:
# [3.610165596008301, 0.1526000052690506]

# %%
class_vals = np.argmax(model.predict(test_x), axis=-1)
class_vals.shape
#test_y.shape
count=0
for i in class_vals:
    if (class_vals[i]==test_y[i]):
        count=count+1
my_acc = count/class_vals.shape[0]
my_acc
# Out:
# 0.0144
